# %% [markdown]
# # Saving NumPy arrays to images

# %%
# Import statements
# %matplotlib inline 
import os
import numpy as np 
import matplotlib.pyplot as plt
from scipy.io import loadmat
from PIL import Image
import matplotlib.image

# %%
# Setting paths
characters_path = 'archive'
diacritics_path = f'{characters_path}/Baybayin Diacritics'

# %%
# Load the data
data = loadmat('/Users/ronnelrobles/Downloads/Find-and-crop-objects-From-images-using-OpenCV-and-Python-master/archive/Baybayin Diacritics/Baybayin_Diacritics.mat')

# %%
# Assigning data
cross_data = data['Baybayin_Diacritics']['Cross'][0][0]
bar_data = data['Baybayin_Diacritics']['Bar'][0][0]
dot_data = data['Baybayin_Diacritics']['Dot'][0][0]
x_data = data['Baybayin_Diacritics']['X'][0][0]

# %%
# Reshaping array to 56x56
cross = np.reshape(cross_data, (500, 56, 56))
bar = np.reshape(bar_data, (500, 56, 56))
dot = np.reshape(dot_data, (500, 56, 56))
x_symbols = np.reshape(x_data, (500, 56, 56))

# %%
# Discovering the minimum and maximum values
print("Min value: " + str(cross[0].min()))
print("Max value: " + str(cross[0].max()))
# Out:
# Min value: 0
# Max value: 1

# %%
# Create folder if not yet present
dir_path = f'{diacritics_path}/x'
os.makedirs(dir_path, exist_ok=True)

# %%
# Looping through the data and saving it to PNG format
for i in range(len(x)):
    fig = plt.figure(frameon=False)
    fig.set_size_inches(1,1)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    fig.patch.set_alpha(0.0)
    ax.imshow(x[i], cmap='Greys', aspect='auto')
    fig.savefig(f'{dir_path}/x-{i+1}.png', transparent=True, format='png', dpi=56)
# Out:
# <ipython-input-127-9c564b592e1e>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(frameon=False)

# %%
# Plotting 100 images
fig, axes = plt.subplots(10,10, figsize=(8,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(c[i])
