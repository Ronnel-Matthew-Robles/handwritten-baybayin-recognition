# %%
# import sys
# !{sys.executable} -m pip install gradio

# %%
import tensorflow as tf
from PIL import Image
import numpy as np
# import gradio as gr
import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model('3-conv-64-nodes-1-dense-512-1669611358')

# %%
labels = ['A',
 'B',
 'BA',
 'BE/BI',
 'BO/BU',
 'D',
 'DA',
 'DE/DI',
 'DO/DU',
 'E/I',
 'G',
 'GA',
 'GE/GI',
 'GO/GU',
 'H',
 'HA',
 'HE/HI',
 'HO/HU',
 'K',
 'KA',
 'KE/KI',
 'KO/KU',
 'L',
 'LA',
 'LE/LI',
 'LO/LU',
 'M',
 'MA',
 'ME/MI',
 'MO/MU',
 'N',
 'NA',
 'NE/NI',
 'NG',
 'NGA',
 'NGE/NGI',
 'NGO/NGU',
 'NO/NU',
 'O/U',
 'P',
 'PA',
 'PE/PI',
 'PO/PU',
 'R',
 'RA',
 'RE/RI',
 'RO/RU',
 'S',
 'SA',
 'SE/SI',
 'SO/SU',
 'T',
 'TA',
 'TE/TI',
 'TO/TU',
 'W',
 'WA',
 'WE/WI',
 'WO/WU',
 'Y',
 'YA',
 'YE/YI',
 'YO/YU']

# %%
def classify_image(inp):
    # i = Image.fromarray(inp, mode="RGB")
    im = inp.convert('L')
    im = im.resize((80,80))
    img_array = np.array(im)
    img_array = np.invert(img_array)
    plt.imshow(img_array)
    print(img_array.shape)
    img_array = img_array.reshape((-1, 80, 80, 1))
    print(img_array.shape)
    prediction = model.predict(img_array)[0]
    print(prediction)
#     confidences = {labels[i]: float(prediction[i]) for i in range(63)}
    confidences = {}
    return confidences

filename = f'cropped/A/A-0.png'
image = Image.open(filename)

classify_image(image)
# Out:
# (80, 80)
# (1, 80, 80, 1)
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 2.9028497e-15
#   0.0000000e+00 0.0000000e+00 0.0000000e+00]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a320e3d489ec> in <module>
#      17 image = Image.open(filename)
#      18
# ---> 19 classify_image(image)
#
# <ipython-input-16-a320e3d489ec> in classify_image(inp)
#      11     prediction = model.predict(img_array)
#      12     print(prediction)
# ---> 13     confidences = {labels[i]: float(prediction[i]) for i in range(63)}
#      14     return confidences
#      15
#
# <ipython-input-16-a320e3d489ec> in <dictcomp>(.0)
#      11     prediction = model.predict(img_array)
#      12     print(prediction)
# ---> 13     confidences = {labels[i]: float(prediction[i]) for i in range(63)}
#      14     return confidences
#      15
#
# TypeError: only size-1 arrays can be converted to Python scalars
